# %%
from backend.tools.rag_tool import search_compliance_docs
print(search_compliance_docs("reason code 10.4 unauthorized card absent"))
# Out:
# [{'text': 'Dispute Condition 10.4: Other Fraud – Card-Absent \nEnvironment for the following reason:', 'section': 'Dispute Condition 10.4', 'page': 698, 'relevance_score': 0.167}, {'text': 'Dispute Condition 11.3: No Authorization/Late Presentment\nInvalid Disputes\nCountry/Region\n\xa0l A Mobile Push Payment Transaction\n\xa0l Where a valid Authorization was required but not obtained for a Credit \nTransaction with one of the following MCCs:\n\xa0– 3000-3350 (Airlines, Air Carriers)\n\xa0– 4111 (Local and Suburban Commuter Passenger Transportation, Including \nFerries) \n\xa0– 4112 (Passenger Railways)\n\xa0– 4131 (Bus Lines)\n\xa0– 4511 (Airlines and Air Carriers [Not Elsewhere Classified])\nAll\nWhere a valid Authorization was required but not obtained for a Transaction that \nboth:\n\xa0l Is processed with a Visa Drive Card that is an “extra” Card which has a Privately \nEurope\nTable 11-48:', 'section': 'Dispute Condition 11.3', 'page': 718, 'relevance_score': 0.042}, {'text': '
# ...

# %%
[{'text': 'Dispute Condition 10.4: Other Fraud – Card-Absent \nEnvironment for the following reason:', 'section': 'Dispute Condition 10.4', 'page': 698, 'relevance_score': 0.167}, {'text': 'Dispute Condition 11.3: No Authorization/Late Presentment\nInvalid Disputes\nCountry/Region\n\xa0l A Mobile Push Payment Transaction\n\xa0l Where a valid Authorization was required but not obtained for a Credit \nTransaction with one of the following MCCs:\n\xa0– 3000-3350 (Airlines, Air Carriers)\n\xa0– 4111 (Local and Suburban Commuter Passenger Transportation, Including \nFerries) \n\xa0– 4112 (Passenger Railways)\n\xa0– 4131 (Bus Lines)\n\xa0– 4511 (Airlines and Air Carriers [Not Elsewhere Classified])\nAll\nWhere a valid Authorization was required but not obtained for a Transaction that \nboth:\n\xa0l Is processed with a Visa Drive Card that is an “extra” Card which has a Privately \nEurope\nTable 11-48:', 'section': 'Dispute Condition 11.3', 'page': 718, 'relevance_score': 0.042}, {'text': 'es\nVisa Product and Service Rules\n11 Dispute Resolution\nVisa Core Rules and Visa Product and Service Rules\n18 April 2026\nVisa Public\n699\n© 2014—2026 Visa. All Rights Reserved.\n\nDispute Condition 10.4: Other Fraud – Card-Absent Environment \nInvalid Disputes\nCountry/Region \n\xa0▪2 (CVV2 value is on the Card but is illegible)\n\xa0▪9 (Cardholder states CVV2 is not present on the Card)\n\xa0l Effective for Disputes processed on or after 18 April 2026 A Card-Absent \nEnvironment Transaction for which both:\n\xa0– The CVV2 result code in the Authorization message is U (Unable to Verify)\n\xa0– The CVV2 presence indicator in the Authorization Request is 1 (CVV2 value \nis present)\n\xa0l For a delayed charge Transaction that relates to a prior stay, trip or rental \nperiod and both:\n\xa0– An Authorization Request that contains both of the following:\n\xa0▪A delayed charge Transaction indicator (field 63.3) message reason code \n3902\n\xa0▪A Transaction ID that links to a prior stay, trip, or rental (field 125 or field \n62.2)\n\xa0– An Electronic Imprint that was obtained  during the same stay, trip, or rental\n\xa0l A Mobile Push Payment Transaction\n\xa0l A Secure Electronic Commerce Transaction processed with Electronic \nCommerce Indicator (ECI) 5 in the Authorization Request, if both of the \nfollowing:  \n\xa0– The Issuer responded to an Authentication Request with an Authentication \nConfirmation using Visa Secure with EMV 3-D Secure (EMV 3DS).\n\xa0– The Cardholder Authentication Verification Value (CAVV) was included in \nthe Authorization Request.\n\xa0l A Secure Electronic Commerce Transaction processed using both an \nAuthenticated Payment Credential and Electronic Commerce Indicator (ECI) 5 \nin the Authorization Request, if both:\n\xa0– The Token Authentication Verification Value (TAVV) was included in the \nAuthorization Request.\n\xa0– The Issuer or Token Requestor approved a Cardholder Verification request \nwith an approved Cardholder Verification Method.\nTable 11-28:', 'section': 'Dispute Condition 10.4', 'page': 700, 'relevance_score': 0.075}]
